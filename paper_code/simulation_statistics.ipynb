# %% [markdown]
# ### Simulation stats
# - Fraction of simulations in which a weapon is aquired
# - Fraction of simulations in which an at-risk location is found
# - Overall probability of a reportable event across cities
