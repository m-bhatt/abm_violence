# %% [markdown]
# ### Data visualization code
# - Distributions of population, population density, and arms density conditional on having had a mass-shooting event or not
# - Heatmap over America of variables, scatterplot of shooting locations superimposed
